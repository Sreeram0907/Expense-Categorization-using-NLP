# %%
import numpy as np
import pandas as pd

# %%
temp_df = pd.read_csv('IMDB Dataset.csv')

# %%
df = temp_df.iloc[:10000]
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['review'][1]
# Out:
# 'A wonderful little production. <br /><br />The filming technique is very unassuming- very old-time-BBC fashion and gives a comforting, and sometimes discomforting, sense of realism to the entire piece. <br /><br />The actors are extremely well chosen- Michael Sheen not only "has got all the polari" but he has all the voices down pat too! You can truly see the seamless editing guided by the references to Williams\' diary entries, not only is it well worth the watching but it is a terrificly written and performed piece. A masterful production about one of the great master\'s of comedy and his life. <br /><br />The realism really comes home with the little things: the fantasy of the guard which, rather than use the traditional \'dream\' techniques remains solid then disappears. It plays on our knowledge and our senses, particularly with the scenes concerning Orton and Halliwell and the sets (particularly of their flat with Halliwell\'s murals decorating every surface) are terribly well done.'

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    5028
# negative    4972
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(17)

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\Sreeram R\AppData\Local\Temp\ipykernel_11440\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Basic Preprocessing
# Remove tags
# lowercase
# remove stopwords

# %%
import re
def remove_tags(raw_text):
    cleaned_text = re.sub(re.compile('<.*?>'), '', raw_text)
    return cleaned_text

# %%
df['review'] = df['review'].apply(remove_tags)
# Out:
# C:\Users\Sreeram R\AppData\Local\Temp\ipykernel_11440\2336150696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(remove_tags)

# %%
df
# Out:
#                                                  review sentiment
# 0     One of the other reviewers has mentioned that ...  positive
# 1     A wonderful little production. The filming tec...  positive
# 2     I thought this was a wonderful way to spend ti...  positive
# 3     Basically there's a family where a little boy ...  negative
# 4     Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                 ...       ...
# 9995  Fun, entertaining movie about WWII German spy ...  positive
# 9996  Give me a break. How can anyone say that this ...  negative
# 9997  This movie is a bad movie. But after watching ...  negative
# 9998  This is a movie that was probably made to ente...  negative
# 9999  Smashing film about film-making. Shows the int...  positive
#
# [9983 rows x 2 columns]

# %%
df['review'] = df['review'].apply(lambda x:x.lower())
# Out:
# C:\Users\Sreeram R\AppData\Local\Temp\ipykernel_11440\740760900.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(lambda x:x.lower())

# %%
from nltk.corpus import stopwords

sw_list = stopwords.words('english')

df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))
# Out:
# C:\Users\Sreeram R\AppData\Local\Temp\ipykernel_11440\2826946130.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review'] = df['review'].apply(lambda x: [item for item in x.split() if item not in sw_list]).apply(lambda x:" ".join(x))

# %%
df
# Out:
#                                                  review sentiment
# 0     one reviewers mentioned watching 1 oz episode ...  positive
# 1     wonderful little production. filming technique...  positive
# 2     thought wonderful way spend time hot summer we...  positive
# 3     basically there's family little boy (jake) thi...  negative
# 4     petter mattei's "love time money" visually stu...  positive
# ...                                                 ...       ...
# 9995  fun, entertaining movie wwii german spy (julie...  positive
# 9996  give break. anyone say "good hockey movie"? kn...  negative
# 9997  movie bad movie. watching endless series bad h...  negative
# 9998  movie probably made entertain middle school, e...  negative
# 9999  smashing film film-making. shows intense stran...  positive
#
# [9983 rows x 2 columns]

# %%
X = df.iloc[:,0:1]
y = df['sentiment']

# %%
X
# Out:
#                                                  review
# 0     one reviewers mentioned watching 1 oz episode ...
# 1     wonderful little production. filming technique...
# 2     thought wonderful way spend time hot summer we...
# 3     basically there's family little boy (jake) thi...
# 4     petter mattei's "love time money" visually stu...
# ...                                                 ...
# 9995  fun, entertaining movie wwii german spy (julie...
# 9996  give break. anyone say "good hockey movie"? kn...
# 9997  movie bad movie. watching endless series bad h...
# 9998  movie probably made entertain middle school, e...
# 9999  smashing film film-making. shows intense stran...
#
# [9983 rows x 1 columns]

# %%
y
# Out:
# 0       positive
# 1       positive
# 2       positive
# 3       negative
# 4       positive
#           ...
# 9995    positive
# 9996    negative
# 9997    negative
# 9998    negative
# 9999    positive
# Name: sentiment, Length: 9983, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

y = encoder.fit_transform(y)
y
# Out:
# array([1, 1, 1, ..., 0, 0, 1])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train.shape
# Out:
# (7986, 1)

# %%
# Applying BoW
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
X_train_bow = cv.fit_transform(X_train['review'])
X_test_bow = cv.transform(X_test['review'])

# %%
X_train_bow.shape
# Out:
# (7986, 48282)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_bow, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test_bow)

from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,y_pred)
# Out:
# 0.8497746619929895

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[836, 116],
#        [184, 861]])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()

rf.fit(X_train_bow,y_train)
y_pred = rf.predict(X_test_bow)
accuracy_score(y_test,y_pred)
# Out:
# 0.8467701552328493

# %%
cv = CountVectorizer(max_features=3000)

X_train_bow = cv.fit_transform(X_train['review']).toarray()
X_test_bow = cv.transform(X_test['review']).toarray()

rf = RandomForestClassifier()

rf.fit(X_train_bow,y_train)
y_pred = rf.predict(X_test_bow)
accuracy_score(y_test,y_pred)
# Out:
# 0.8432648973460191

# %%
cv = CountVectorizer(ngram_range=(1,2),max_features=5000)

X_train_bow = cv.fit_transform(X_train['review']).toarray()
X_test_bow = cv.transform(X_test['review']).toarray()

rf = RandomForestClassifier()

rf.fit(X_train_bow,y_train)
y_pred = rf.predict(X_test_bow)
accuracy_score(y_test,y_pred)
# Out:
# 0.8402603905858789

# %% [markdown]
# Using Tfidf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
X_train_tfidf = tfidf.fit_transform(X_train['review'])
X_test_tfidf = tfidf.transform(X_test['review'])

# %%
rf = RandomForestClassifier()

rf.fit(X_train_tfidf,y_train)
y_pred = rf.predict(X_test_tfidf)

accuracy_score(y_test,y_pred)
# Out:
# 0.8457686529794692

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp311-cp311-win_amd64.whl.metadata (8.2 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Downloading gensim-4.3.3-cp311-cp311-win_amd64.whl (24.0 MB)
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.0 MB 5.6 MB/s eta 0:00:05
#    -- ------------------------------------- 1.6/24.0 MB 7.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.1/24.0 MB 6.2 MB/s eta 0:00:04
#    ------ --------------------------------- 4.2/24.0 MB 5.6 MB/s eta 0:00:04
#    -------- ------------------------------- 5.0/24.0 MB 5.3 MB/s eta 0:00:04
#    --------- ------------------------------ 5.8/24.0 MB 5.2 MB/s eta 0:00:04
#    ------------ --------------------------- 7.6/24.0 MB 5.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 9.7/24.0 MB 6.2 MB/s eta 0:00:03
#    ------------------- -------------------- 11.5/24.0 MB 6.5 MB/s eta 0:00:02
#    -------------------- ------------------- 12.6/24.0 MB 6.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.6/24.0 MB 6.3 MB/s eta 0:00:02
#    ------------------------ --------------- 14.7/24.0 MB 6.2 MB/s eta 0:00:02
#    -------------------------- ------------- 15.7/24.0 MB 6.0 MB/s eta 0:00:02
#    --------------------------- ------------ 16.5/24.0 MB 5.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 17.8/24.0 MB 5.9 MB/s eta 0:00:02
#    -------------------------------- ------- 19.4/24.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.0/24.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 22.5/24.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  23.9/24.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 24.0/24.0 MB 6.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.6/15.8 MB 8.4 MB/s eta 0:00:02
#    ------- -------------------------------- 3.1/15.8 MB 7.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.5/15.8 MB 7.1 MB/s eta 0:00:02
#    ------------- -------------------------- 5.5/15.8 MB 6.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.8/15.8 MB 6.5 MB/s eta 0:00:02
#    -------------------- ------------------- 8.1/15.8 MB 6.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 9.4/15.8 MB 6.5 MB/s eta 0:00:01
#    --------------------------- ------------ 10.7/15.8 MB 6.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.1/15.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------- -- 14.9/15.8 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 6.5 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    - -------------------------------------- 1.3/46.2 MB 7.4 MB/s eta 0:00:07
#    -- ------------------------------------- 2.9/46.2 MB 7.0 MB/s eta 0:00:07
#    --- ------------------------------------ 4.5/46.2 MB 7.1 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.5/46.2 MB 6.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 6.6/46.2 MB 6.2 MB/s eta 0:00:07
#    ------ --------------------------------- 7.1/46.2 MB 5.9 MB/s eta 0:00:07
#    ------- -------------------------------- 8.4/46.2 MB 5.7 MB/s eta 0:00:07
#    -------- ------------------------------- 9.4/46.2 MB 5.6 MB/s eta 0:00:07
#    --------- ------------------------------ 10.5/46.2 MB 5.6 MB/s eta 0:00:07
#    --------- ------------------------------ 11.5/46.2 MB 5.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 12.8/46.2 MB 5.6 MB/s eta 0:00:07
#    ------------ --------------------------- 13.9/46.2 MB 5.6 MB/s eta 0:00:06
#    ------------ --------------------------- 14.9/46.2 MB 5.6 MB/s eta 0:00:06
#    ------------- -------------------------- 16.0/46.2 MB 5.5 MB/s eta 0:00:06
#    -------------- ------------------------- 16.8/46.2 MB 5.4 MB/s eta 0:00:06
#    --------------- ------------------------ 17.6/46.2 MB 5.3 MB/s eta 0:00:06
#    ---------------- ----------------------- 18.6/46.2 MB 5.2 MB/s eta 0:00:06
#    ---------------- ----------------------- 19.4/46.2 MB 5.2 MB/s eta 0:00:06
#    ----------------- ---------------------- 20.2/46.2 MB 5.1 MB/s eta 0:00:06
#    ------------------ --------------------- 21.2/46.2 MB 5.1 MB/s eta 0:00:05
#    ------------------- -------------------- 22.0/46.2 MB 5.0 MB/s eta 0:00:05
#    ------------------- -------------------- 22.8/46.2 MB 5.0 MB/s eta 0:00:05
#    -------------------- ------------------- 23.6/46.2 MB 5.0 MB/s eta 0:00:05
#    --------------------- ------------------ 24.6/46.2 MB 4.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 25.4/46.2 MB 4.9 MB/s eta 0:00:05
#    ---------------------- ----------------- 26.5/46.2 MB 4.9 MB/s eta 0:00:05
#    ----------------------- ---------------- 27.3/46.2 MB 4.8 MB/s eta 0:00:04
#    ------------------------ --------------- 28.0/46.2 MB 4.8 MB/s eta 0:00:04
#    ------------------------ --------------- 28.8/46.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------- -------------- 29.4/46.2 MB 4.7 MB/s eta 0:00:04
#    ------------------------- -------------- 29.9/46.2 MB 4.6 MB/s eta 0:00:04
#    -------------------------- ------------- 30.7/46.2 MB 4.6 MB/s eta 0:00:04
#    --------------------------- ------------ 31.2/46.2 MB 4.6 MB/s eta 0:00:04
#    --------------------------- ------------ 32.0/46.2 MB 4.5 MB/s eta 0:00:04
#    ---------------------------- ----------- 32.5/46.2 MB 4.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 32.8/46.2 MB 4.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 33.6/46.2 MB 4.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 34.1/46.2 MB 4.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 34.6/46.2 MB 4.3 MB/s eta 0:00:03
#    ------------------------------ --------- 35.4/46.2 MB 4.2 MB/s eta 0:00:03
#    ------------------------------- -------- 35.9/46.2 MB 4.2 MB/s eta 0:00:03
#    ------------------------------- -------- 36.7/46.2 MB 4.1 MB/s eta 0:00:03
#    -------------------------------- ------- 37.0/46.2 MB 4.1 MB/s eta 0:00:03
#    -------------------------------- ------- 37.2/46.2 MB 4.0 MB/s eta 0:00:03
#    -------------------------------- ------- 38.0/46.2 MB 4.0 MB/s eta 0:00:03
#    --------------------------------- ------ 38.5/46.2 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 39.1/46.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 39.8/46.2 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 40.4/46.2 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 40.9/46.2 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 41.7/46.2 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------ --- 42.2/46.2 MB 3.8 MB/s eta 0:00:02
#    ------------------------------------- -- 43.0/46.2 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------- -- 43.5/46.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 44.3/46.2 MB 3.8 MB/s eta 0:00:01
#    -------------------------------------- - 44.8/46.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  45.6/46.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 3.7 MB/s eta 0:00:00
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
# Downloading wrapt-1.17.2-cp311-cp311-win_amd64.whl (38 kB)
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.0.1
#
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#     Uninstalling numpy-2.0.1:
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#       Successfully uninstalled numpy-2.0.1
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    -------- ------------------------------- 1/5 [numpy]
#    ---------------- ----------------------- 2/5 [smart-open]
#   Attempting uninstall: scipy
#    ---------------- ----------------------- 2/5 [smart-open]
#     Found existing installation: scipy 1.14.1
#    ---------------- ----------------------- 2/5 [smart-open]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#     Uninstalling scipy-1.14.1:
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#       Successfully uninstalled scipy-1.14.1
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    ------------------------ --------------- 3/5 [scipy]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    -------------------------------- ------- 4/5 [gensim]
#    ---------------------------------------- 5/5 [gensim]
#
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1 smart-open-7.1.0 wrapt-1.17.2
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\~cipy'.
#   You can safely remove it manually.

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 import gensim
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
from gensim.models import Word2Vec,KeyedVectors
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 from gensim.models import Word2Vec,KeyedVectors
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\matutils.py:1034
#    1029     return 1. - float(len(set1 & set2)) / float(union_cardinality)
#    1032 try:
#    1033     # try to load fast, cythonized code if possible
# -> 1034     from gensim._matutils import logsumexp, mean_absolute_difference, dirichlet_expectation
#    1036 except ImportError:
#    1037     def logsumexp(x):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\_matutils.pyx:1, in init gensim._matutils()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
pip uninstall gensim numpy -y
# Out:
# Found existing installation: gensim 4.3.3
# Uninstalling gensim-4.3.3:
#   Successfully uninstalled gensim-4.3.3
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\~ensim'.
# You can safely remove it manually.

# %%
pip install numpy==1.24.3 gensim==4.3.1
# Out:
# Collecting numpy==1.24.3Note: you may need to restart the kernel to use updated packages.
#
#   Downloading numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting gensim==4.3.1
#   Downloading gensim-4.3.1-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from gensim==4.3.1) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from gensim==4.3.1) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from smart-open>=1.8.1->gensim==4.3.1) (1.17.2)
# Downloading numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.3/14.8 MB 6.1 MB/s eta 0:00:03
#    --------- ------------------------------ 3.4/14.8 MB 7.5 MB/s eta 0:00:02
#    -------------- ------------------------- 5.5/14.8 MB 8.2 MB/s eta 0:00:02
#    -------------------- ------------------- 7.6/14.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.4/14.8 MB 7.6 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.8 MB 7.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.5/14.8 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 11.5/14.8 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 12.3/14.8 MB 6.5 MB/s eta 0:00:01
#    ------------------------------------ --- 13.6/14.8 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.8 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 14.8/14.8 MB 6.1 MB/s eta 0:00:00
# Downloading gensim-4.3.1-cp311-cp311-win_amd64.whl (23.9 MB)
#    ---------------------------------------- 0.0/23.9 MB ? eta -:--:--
#    - -------------------------------------- 1.0/23.9 MB 6.3 MB/s eta 0:00:04
#    --- ------------------------------------ 2.1/23.9 MB 6.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.1/23.9 MB 4.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/23.9 MB 4.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/23.9 MB 4.9 MB/s eta 0:00:05
#    ------- -------------------------------- 4.2/23.9 MB 3.5 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/23.9 MB 3.5 MB/s eta 0:00:06
#    -------- ------------------------------- 5.2/23.9 MB 3.5 MB/s eta 0:00:06
#    ---------- ----------------------------- 6.3/23.9 MB 3.3 MB/s eta 0:00:06
#    ------------ --------------------------- 7.3/23.9 MB 3.5 MB/s eta 0:00:05
#    ------------ --------------------------- 7.3/23.9 MB 3.5 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/23.9 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/23.9 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/23.9 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/23.9 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.4/23.9 MB 3.3 MB/s eta 0:00:05
#    -------------- ------------------------- 8.9/23.9 MB 2.5 MB/s eta 0:00:07
#    --------------- ------------------------ 9.4/23.9 MB 2.5 MB/s eta 0:00:06
#    --------------- ------------------------ 9.4/23.9 MB 2.5 MB/s eta 0:00:06
#    --------------- ------------------------ 9.4/23.9 MB 2.5 MB/s eta 0:00:06
#    ----------------- ---------------------- 10.2/23.9 MB 2.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 10.5/23.9 MB 2.3 MB/s eta 0:00:06
#    ----------------- ---------------------- 10.5/23.9 MB 2.3 MB/s eta 0:00:06
#    ------------------- -------------------- 11.5/23.9 MB 2.3 MB/s eta 0:00:06
#    --------------------- ------------------ 12.6/23.9 MB 2.4 MB/s eta 0:00:05
#    --------------------- ------------------ 12.6/23.9 MB 2.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 13.9/23.9 MB 2.4 MB/s eta 0:00:05
#    ------------------------ --------------- 14.7/23.9 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 14.7/23.9 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 14.7/23.9 MB 2.5 MB/s eta 0:00:04
#    -------------------------- ------------- 15.7/23.9 MB 2.4 MB/s eta 0:00:04
#    --------------------------- ------------ 16.3/23.9 MB 2.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 17.3/23.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.8/23.9 MB 2.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 17.8/23.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------ --------- 18.4/23.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------------- -------- 18.9/23.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------- -------- 18.9/23.9 MB 2.5 MB/s eta 0:00:03
#    ------------------------------- -------- 18.9/23.9 MB 2.5 MB/s eta 0:00:03
#    -------------------------------- ------- 19.4/23.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/23.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/23.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/23.9 MB 2.3 MB/s eta 0:00:02
#    --------------------------------- ------ 19.9/23.9 MB 2.3 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.9 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.9 MB 2.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 21.0/23.9 MB 2.2 MB/s eta 0:00:02
#    ------------------------------------ --- 22.0/23.9 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 22.3/23.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 23.1/23.9 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/23.9 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 23.9/23.9 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: numpy, gensim
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.3.1 numpy-1.24.3

# %%
# !pip show gensim
# Out:
# Name: gensim
# Version: 4.3.1
# Summary: Python framework for fast Vector Space Modelling
# Home-page: http://radimrehurek.com/gensim
# Author: Radim Rehurek
# Author-email: me@radimrehurek.com
# License: LGPL-2.1-only
# Location: C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages
# Requires: numpy, scipy, smart-open
# Required-by:

# %%
import sys
import numpy
print(sys.version)
print("NumPy version:", numpy.__version__)
# Out:
# 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]
# NumPy version: 2.0.1

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.24.3
# Out:
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Successfully uninstalled numpy-1.24.3
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.24.3

# %%
print("NumPy version:", numpy.__version__)
# Out:
# NumPy version: 2.0.1

# %%
# !pip uninstall -y numpy
# Out:
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Successfully uninstalled numpy-1.24.3

# %%
# !pip install numpy==1.24.3
# Out:
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.24.3

# %%
# !pip uninstall -y gensim numpy
# Out:
# Found existing installation: gensim 4.3.1
# Uninstalling gensim-4.3.1:
#   Successfully uninstalled gensim-4.3.1
# Found existing installation: numpy 1.24.3
# Uninstalling numpy-1.24.3:
#   Successfully uninstalled numpy-1.24.3

# %%
# !pip install numpy==1.24.3 gensim==4.3.1
# Out:
# Collecting numpy==1.24.3
#   Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# Collecting gensim==4.3.1
#   Using cached gensim-4.3.1-cp311-cp311-win_amd64.whl.metadata (8.5 kB)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from gensim==4.3.1) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from gensim==4.3.1) (7.1.0)
# Requirement already satisfied: wrapt in c:\users\sreeram r\appdata\local\programs\python\python311\lib\site-packages (from smart-open>=1.8.1->gensim==4.3.1) (1.17.2)
# Using cached numpy-1.24.3-cp311-cp311-win_amd64.whl (14.8 MB)
# Using cached gensim-4.3.1-cp311-cp311-win_amd64.whl (23.9 MB)
# Installing collected packages: numpy, gensim
#
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    ---------------------------------------- 0/2 [numpy]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    -------------------- ------------------- 1/2 [gensim]
#    ---------------------------------------- 2/2 [gensim]
#
# Successfully installed gensim-4.3.1 numpy-1.24.3

# %%
import gensim
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gensim
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.1'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\gensim\matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (C:\Users\Sreeram R\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\linalg\__init__.py)
